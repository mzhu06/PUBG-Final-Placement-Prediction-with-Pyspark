# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
import warnings
warnings.filterwarnings("ignore")

# %%
train = pd.read_csv('sampleTrain.csv')

# %%
sns.set()
cols = ['winPlacePerc', 'walkDistance', 'boosts', 'weaponsAcquired', 'damageDealt', 'killPlace']
g = sns.pairplot(train[cols], size = 2.5,diag_kind="kde")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-44955e873896> in <module>
#       4
#       5 plt.show()
# ----> 6 plt.save()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'save'

# %%
sns.pairplot(train[cols], size = 2.5,diag_kind="kde").savefig("output.png")

# %%
sns.set()
cols = ['winPlacePerc', 'walkDistance', 'boosts', 'weaponsAcquired', 'damageDealt', 'killPlace']
sns.pairplot(train[cols], size = 2.5,diag_kind="reg")
 
plt.show()
